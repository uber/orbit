# %% [markdown]
# # Diagnostic Visualization demo

# %% [markdown]
# In this demo, we want to demonstrate how to use the plotting utilities to visualize the posterior samples of Orbit MCMC models.
#
# We leveraged [arviz](https://arviz-devs.github.io/arviz/index.html) for the plots. ArviZ is a Python package for exploratory analysis of Bayesian models, includes functions for posterior analysis, data storage, model checking, comparison and diagnostics.

# %%
import pandas as pd
import numpy as np
from orbit.models.lgt import LGTFull
from orbit.models.dlt import DLTFull
import arviz as az
from orbit.utils.dataset import load_iclaims
from orbit.diagnostics.plot import plot_param_diagnostics

import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ## Load data

# %%
raw_df = load_iclaims()
raw_df.dtypes
# Out:
# week              datetime64[ns]
# claims                   float64
# trend.unemploy           float64
# trend.filling            float64
# trend.job                float64
# sp500                    float64
# vix                      float64
# dtype: object

# %%
raw_df.head(5)
# Out:
#         week     claims  trend.unemploy  trend.filling  trend.job     sp500  \
# 0 2010-01-03  13.386595        0.219882      -0.318452   0.117500 -0.417633
# 1 2010-01-10  13.624218        0.219882      -0.194838   0.168794 -0.425480
# 2 2010-01-17  13.398741        0.236143      -0.292477   0.117500 -0.465229
# 3 2010-01-24  13.137549        0.203353      -0.194838   0.106918 -0.481751
# 4 2010-01-31  13.196760        0.134360      -0.242466   0.074483 -0.488929
#
#         vix
# 0  0.122654
# 1  0.110445
# 2  0.532339
# 3  0.428645
# 4  0.487404

# %%
df=raw_df.copy()
test_size=52
train_df=df[:-test_size]
test_df=df[-test_size:]

# %% [markdown]
# ## Fit a Model

# %%
DATE_COL="week"
RESPONSE_COL="claims"
REGRESSOR_COL=['trend.unemploy', 'trend.filling', 'trend.job']

# %%
dlt = DLTFull(
    response_col=RESPONSE_COL,
    date_col=DATE_COL,
    regressor_col=REGRESSOR_COL,
    regressor_sign=["+", '+', '='], 
    seasonality=52,
    num_warmup=2000,
    num_sample=2000,
    chains=4,
)

# %%
dlt.fit(df=train_df)
# Out:
# WARNING:pystan:Maximum (flat) parameter count (1000) exceeded: skipping diagnostic tests for n_eff and Rhat.
# To run all diagnostics call pystan.check_hmc_diagnostics(fit)

# %% [markdown]
# ## Posterior Diagnostic Viz

# %% [markdown]
# ### trace plot

# %%
plot_param_diagnostics(dlt, which='trace', kind="trace", 
                       legend=True,
                       chain_prop={"color": ["r", "b","g","y"]});

# %%
plot_param_diagnostics(dlt, which='trace', kind="rank_bars",
                       legend=True,
                       chain_prop={"color": ["r", "b","g","y"]});

# %%
plot_param_diagnostics(dlt, which='trace', kind="rank_vlines",
                       legend=True,
                       chain_prop={"color": ["r", "b","g","y"]});

# %% [markdown]
# ### density plot

# %%
plot_param_diagnostics(dlt, which='density');

# %% [markdown]
# ### pair plot

# %%
plot_param_diagnostics(dlt, which='pair');

# %% [markdown]
# ### forest plot

# %%
plot_param_diagnostics(dlt, which='forest');

# %%
plot_param_diagnostics(dlt, which='forest', kind='ridgeplot', colors='white', combined=True);

# %% [markdown]
# ### posterior plot

# %%
plot_param_diagnostics(dlt, which='posterior');

# %% [markdown]
# ### autocorr plot

# %%
plot_param_diagnostics(dlt, which='autocorr');
